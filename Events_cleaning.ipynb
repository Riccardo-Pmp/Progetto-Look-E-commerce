# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_events=pd.read_csv('events.csv')
df_events
# Out:
#               id  user_id                  city      state  browser  \
# 0         193079    14759             São Paulo  São Paulo   Chrome
# 1         157237    12062             São Paulo  São Paulo   Chrome
# 2        1290688    99790             São Paulo  São Paulo   Safari
# 3         234294    17942             São Paulo  São Paulo   Chrome
# 4        1145403    88606             São Paulo  São Paulo  Firefox
# ...          ...      ...                   ...        ...      ...
# 1293921   610734    46935                London    England   Chrome
# 1293922  1233354    95411            Sunderland    England       IE
# 1293923  1229153    95090                London    England   Chrome
# 1293924   552834    42491         Middlesbrough    England  Firefox
# 1293925   410614    31417  Ashton-in-Makerfield    England   Chrome
#
#         traffic_source event_type creation_date order_time
# 0              Adwords       cart    2022-10-07   08:35:50
# ...

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293926 entries, 0 to 1293925
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   id              1293926 non-null  int64
#  1   user_id         1293926 non-null  int64
#  2   city            1281000 non-null  object
#  3   state           1293926 non-null  object
#  4   browser         1293926 non-null  object
#  5   traffic_source  1293926 non-null  object
#  6   event_type      1293926 non-null  object
#  7   creation_date   1293926 non-null  object
#  8   order_time      1293926 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 88.8+ MB

# %%
df_events.shape
# Out:
# (1293926, 9)

# %%
df_events['creation_date'] = pd.to_datetime(df_events['creation_date'])

# %%
df_events['city'].unique()
# Out:
# array(['São Paulo', 'Embu-Guaçu', 'Cajamar', ..., 'Orthez',
#        'Gibson Desert North', 'High stone market'],
#       shape=(7532,), dtype=object)

# %%
df_events['state'].unique()
# Out:
# array(['São Paulo', 'Brussels', 'Beijing', 'New York', 'Extremadura',
#        'Inner Mongolia Autonomous Region', 'Berlin', 'Tokyo', 'Liaoning',
#        'Sachsen', 'Seoul', 'Comunidad Valenciana', 'Jilin',
#        "Provence-Alpes-Côte d'Azur", 'Castilla-La Mancha', 'Andalucía',
#        'Brandenburg', 'Heilongjiang', 'Galicia', 'Pennsylvania',
#        'Flanders', 'Cataluña', 'Massachusetts', 'Delaware', 'Shanghai',
#        'New South Wales', 'País Vasco', 'Virginia', 'Maryland',
#        'Rio de Janeiro', 'Jiangsu', 'Hamburg', 'Niedersachsen',
#        'Kanagawa', 'Bourgogne-Franche-Comté', 'Aragón', 'Anhui',
#        'Castilla y León', 'Shandong', 'Schleswig-Holstein', 'La Rioja',
#        'Chiba', 'Auvergne-Rhône-Alpes', 'Normandie', 'North Carolina',
#        'Bremen', 'Comunidad de Madrid', 'Centre-Val de Loire',
#        'Rhode Island', 'Bretagne', 'Espírito Santo', 'South Carolina',
#        'Shanxi', 'Georgia', 'Tianjin', 'Victoria', 'Daejeon', 'Occitanie',
# ...

# %%
missing = df_events.isnull().sum()
missing_pct = (missing / len(df_events) * 100).round(2)

missing_df = pd.DataFrame({
    'Valori Nulli': missing,
    'Percentuale (%)': missing_pct
})

print("Valori mancanti per colonna:")
print(missing_df[missing_df['Valori Nulli'] > 0].sort_values('Valori Nulli', ascending=False))
# Out:
# Valori mancanti per colonna:
#       Valori Nulli  Percentuale (%)
# city         12926              1.0

# %%
df_events[df_events['city'].isna()]
# Out:
#               id  user_id city                state  browser traffic_source  \
# 270       844564    65084  NaN              Galicia  Firefox        Adwords
# 496       533538    40987  NaN             Virginia   Chrome        Adwords
# 685       802472    61942  NaN  Comunidad de Madrid   Chrome        Adwords
# 698       913670    70534  NaN            Andalucía   Safari        Adwords
# 699      1119906    86643  NaN       Espírito Santo       IE        Adwords
# ...          ...      ...  ...                  ...      ...            ...
# 1293787  1095535    84706  NaN                 Pará  Firefox        YouTube
# 1293789   170347    13052  NaN                 Pará   Safari        YouTube
# 1293790   520839    39949  NaN                 Pará   Chrome        YouTube
# 1293792   124313     9554  NaN                 Pará   Chrome        YouTube
# 1293795   637983    49150  NaN                Amapá       IE        YouTube
#
#         event_type creation_date order_time
# ...

# %%
df_events[df_events['user_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, user_id, city, state, browser, traffic_source, event_type, creation_date, order_time]
# Index: []

# %%
df_1=pd.read_csv('df_events.csv')
df_1
# Out:
#               id  user_id        city      state  browser traffic_source  \
# 0         137338    10589     Sapporo   Hokkaido   Chrome        Adwords
# 1         445862    33856    Oshu-shi      Iwate    Other        Adwords
# 2        1298049    99501   São Paulo  São Paulo   Chrome        Adwords
# 3        1239991    95100   São Paulo  São Paulo   Chrome        Adwords
# 4         772152    58975   São Paulo  São Paulo    Other        Adwords
# ...          ...      ...         ...        ...      ...            ...
# 1304366   695368    53139  Portsmouth    England  Firefox        YouTube
# 1304367   471487    35871   Eastleigh    England   Chrome        YouTube
# 1304368    14240     1054   St Helens    England    Other        YouTube
# 1304369   613940    46943  Warrington    England   Chrome        YouTube
# 1304370   584336    44698     Watford    England   Chrome        YouTube
#
#         event_type creation_date order_time
# 0             cart    2023-01-11   18:25:29
# ...

# %%
df_1[df_1['id']=='1759151']
# Out:
# Empty DataFrame
# Columns: [id, user_id, city, state, browser, traffic_source, event_type, creation_date, order_time]
# Index: []

# %%
df_2=pd.read_csv('prova.csv')
df_2
# Out:
#               id  user_id                 city      state  browser  \
# 0        1843936      NaN            São Paulo  São Paulo   Safari
# 1        1366432      NaN            São Paulo  São Paulo   Chrome
# 2        1791971      NaN  Rio Grande da Serra  São Paulo   Chrome
# 3        1416261      NaN             Changzhi    Beijing  Firefox
# 4        1539705      NaN              Chizhou    Beijing   Chrome
# ...          ...      ...                  ...        ...      ...
# 2428186    94213   7281.0               London    England  Firefox
# 2428187    33200   2555.0          Farnborough    England  Firefox
# 2428188   116772   9011.0       West Bridgford    England       IE
# 2428189   459408  34950.0            Donington    England  Firefox
# 2428190   430710  32743.0        Pontarddulais      Wales   Safari
#
#         traffic_source event_type creation_date order_time
# 0              Adwords     cancel    2020-03-03   01:59:00
# ...

# %%
df_1[df_1['user_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, user_id, city, state, browser, traffic_source, event_type, creation_date, order_time]
# Index: []
