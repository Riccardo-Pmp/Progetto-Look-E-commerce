# %%
import numpy as np
import pandas as pd

# %%
df_pf = pd.read_csv("D:/R/boolean/progetto finale/tabelle big query/Users.csv")
df_pf.head(20)
# Out:
#        id  age gender state      city country traffic_source  \
# 0   19915   58      M  Acre       NaN  Brasil        Display
# 1   39989   27      F  Acre       NaN  Brasil         Search
# 2   96778   20      F  Acre       NaN  Brasil        Organic
# 3   99872   30      F  Acre       NaN  Brasil         Search
# 4   30102   53      F  Acre       NaN  Brasil         Search
# 5   11649   40      M  Acre       NaN  Brasil         Search
# 6   33559   32      M  Acre       NaN  Brasil         Search
# 7   41015   13      M  Acre       NaN  Brasil         Search
# 8    1660   12      M  Acre       NaN  Brasil         Search
# 9   56594   15      M  Acre       NaN  Brasil        Organic
# 10  25885   47      F  Acre       NaN  Brasil         Search
# 11  83592   58      M  Acre       NaN  Brasil        Organic
# 12  81897   41      M  Acre  Tarauacá  Brasil         Search
# 13  12320   36      M  Acre  Tarauacá  Brasil         Search
# ...

# %%
print(df_pf.shape)
# Out:
# (100000, 8)

# %%
df_pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              100000 non-null  int64
#  1   age             100000 non-null  int64
#  2   gender          100000 non-null  object
#  3   state           100000 non-null  object
#  4   city            99030 non-null   object
#  5   country         100000 non-null  object
#  6   traffic_source  100000 non-null  object
#  7   FullName        100000 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 6.1+ MB

# %%
df_pf["age"].describe().round(2)
# Out:
# count    100000.00
# mean         41.00
# std          16.97
# min          12.00
# 25%          26.00
# 50%          41.00
# 75%          56.00
# max          70.00
# Name: age, dtype: float64

# %%
min_age = df_pf["age"].min()
max_age = df_pf["age"].max()
print("Minimum age:", min_age)
print("Maximum age:", max_age)
# Out:
# Minimum age: 12
# Maximum age: 70

# %%
age_under_18 = []
age_under_40 = []
age_under_70 = []
for A in df_pf["age"]:
    if A < 18:
        age_under_18.append(A)
    elif A < 40:
        age_under_40.append(A)      
    else:
        age_under_70.append(A)
print("Number of users under 18:", len(age_under_18))
print("Number of users under 40:", len(age_under_40))                
print("Number of users under 70:", len(age_under_70))
# Out:
# Number of users under 18: 10059
# Number of users under 40: 37425
# Number of users under 70: 52516

# %%
gender_M = []
gender_F = []

for G in df_pf["gender"]:
    if G == "M":
        gender_M.append(G)
    elif G == "F":
        gender_F.append(G)

print("Number of male users:", len(gender_M))
print("Number of female users:", len(gender_F))
# Out:
# Number of male users: 49774
# Number of female users: 50226

# %%
print(df_pf["age"].value_counts().sort_index())
# Out:
# age
# 12    1670
# 13    1670
# 14    1656
# 15    1723
# 16    1623
# 17    1717
# 18    1689
# 19    1724
# 20    1723
# 21    1634
# 22    1702
# 23    1685
# 24    1630
# 25    1643
# 26    1681
# 27    1715
# 28    1735
# 29    1671
# 30    1711
# 31    1753
# 32    1670
# 33    1682
# 34    1743
# 35    1771
# 36    1667
# 37    1698
# 38    1688
# 39    1810
# 40    1734
# 41    1658
# 42    1680
# 43    1706
# 44    1731
# 45    1685
# 46    1711
# 47    1694
# 48    1685
# 49    1758
# 50    1749
# 51    1725
# 52    1721
# 53    1689
# 54    1701
# 55    1742
# 56    1622
# 57    1683
# 58    1713
# 59    1670
# 60    1743
# 61    1615
# 62    1598
# 63    1673
# 64    1728
# 65    1674
# 66    1708
# 67    1657
# 68    1664
# 69    1721
# 70    1678
# Name: count, dtype: int64

# %%
tf = df_pf["traffic_source"].unique()
print(tf)
# Out:
# ['Display' 'Search' 'Organic' 'Facebook' 'Email']

# %%
print(df_pf["traffic_source"].value_counts())
# Out:
# traffic_source
# Search      69995
# Organic     15095
# Facebook     5888
# Email        5006
# Display      4016
# Name: count, dtype: int64

# %%
df_pf[df_pf['city'].isnull()]
# Out:
#           id  age gender       state city        country traffic_source  \
# 0      19915   58      M        Acre  NaN         Brasil        Display
# 1      39989   27      F        Acre  NaN         Brasil         Search
# 2      96778   20      F        Acre  NaN         Brasil        Organic
# 3      99872   30      F        Acre  NaN         Brasil         Search
# 4      30102   53      F        Acre  NaN         Brasil         Search
# ...      ...  ...    ...         ...  ...            ...            ...
# 93843  96017   58      M    Virginia  NaN  United States         Search
# 93844  64918   18      F    Virginia  NaN  United States         Search
# 94991  39981   35      F  Washington  NaN  United States         Search
# 94992  97500   50      F  Washington  NaN  United States         Search
# 94993  46791   25      F  Washington  NaN  United States        Display
#
#               FullName
# 0        Kenneth Berry
# 1      Laurie Crawford
# 2        Erika Stevens
# ...

# %%
print(df_pf["age"].isna().sum())
print(df_pf["gender"].isna().sum())
print(df_pf["state"].isna().sum())
print(df_pf["city"].isna().sum())
print(df_pf["country"].isna().sum())
print(df_pf["traffic_source"].isna().sum())
# Out:
# 0
# 0
# 0
# 970
# 0
# 0

# %%
anoma_age=[]
for i in df_pf.index:
    if df_pf.loc[i,"age"] > 80:
      anoma_age.append(df_pf.loc[i,"age"])
    if len (anoma_age) > 80:
      print ("wrong") 
    else:
       print ("good")
print("Number of anomalous ages:", len(anoma_age))
# Out:
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# good
# ...

# %%
df_pf["city"] = df_pf["city"].fillna("n.d.")

# %%
df_pf.head(30)
# Out:
#        id  age gender state            city country traffic_source  \
# 0   19915   58      M  Acre            n.d.  Brasil        Display
# 1   39989   27      F  Acre            n.d.  Brasil         Search
# 2   96778   20      F  Acre            n.d.  Brasil        Organic
# 3   99872   30      F  Acre            n.d.  Brasil         Search
# 4   30102   53      F  Acre            n.d.  Brasil         Search
# 5   11649   40      M  Acre            n.d.  Brasil         Search
# 6   33559   32      M  Acre            n.d.  Brasil         Search
# 7   41015   13      M  Acre            n.d.  Brasil         Search
# 8    1660   12      M  Acre            n.d.  Brasil         Search
# 9   56594   15      M  Acre            n.d.  Brasil        Organic
# 10  25885   47      F  Acre            n.d.  Brasil         Search
# 11  83592   58      M  Acre            n.d.  Brasil        Organic
# 12  81897   41      M  Acre        Tarauacá  Brasil         Search
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x="age", data=df_pf)
plt.show()

# %%
df_pf.to_csv("users.csv", index=False)
